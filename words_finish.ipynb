# %%
import pandas as pd    
import numpy as np

import re
import nltk
from nltk.corpus import stopwords
from bs4 import BeautifulSoup

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
train_data = pd.read_csv('words_datasets/labeledTrainData.tsv.zip', delimiter="\t")
test_data = pd.read_csv('words_datasets/testData.tsv.zip', delimiter="\t")

# %%
train_data
# Out:
#             id  sentiment                                             review
# 0       5814_8          1  With all this stuff going down at the moment w...
# 1       2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2       7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3       3630_4          0  It must be assumed that those who praised this...
# 4       9495_8          1  Superbly trashy and wondrously unpretentious 8...
# ...        ...        ...                                                ...
# 24995   3453_3          0  It seems like more consideration has gone into...
# 24996   5064_1          0  I don't believe they made this film. Completel...
# 24997  10905_3          0  Guy is a loser. Can't get girls, needs to buil...
# 24998  10194_3          0  This 30 minute documentary Buñuel made in the ...
# 24999   8478_8          1  I saw this movie as a child and it broke my he...
#
# [25000 rows x 3 columns]

# %%
test_data
# Out:
#              id                                             review
# 0      12311_10  Naturally in a film who's main themes are of m...
# 1        8348_2  This movie is a disaster within a disaster fil...
# 2        5828_4  All in all, this is a movie for kids. We saw i...
# 3        7186_2  Afraid of the Dark left me with the impression...
# 4       12128_7  A very accurate depiction of small time mob li...
# ...         ...                                                ...
# 24995   2155_10  Sony Pictures Classics, I'm looking at you! So...
# 24996     59_10  I always felt that Ms. Merkerson had never got...
# 24997    2531_1  I was so disappointed in this movie. I am very...
# 24998    7772_8  From the opening sequence, filled with black a...
# 24999  11465_10  This is a great horror film for people who don...
#
# [25000 rows x 2 columns]

# %%
# Шаг 1. Добавил разграничение для тестовых и тренировочных данных
train_data['is_test'] = 0
test_data['is_test'] = 1

# %%
# Шаг 2. Объединим данные
dataset = train_data.append(test_data, ignore_index=True)
dataset
# Out:
#              id  sentiment                                             review  \
# 0        5814_8        1.0  With all this stuff going down at the moment w...
# 1        2381_9        1.0  \The Classic War of the Worlds\" by Timothy Hi...
# 2        7759_3        0.0  The film starts with a manager (Nicholas Bell)...
# 3        3630_4        0.0  It must be assumed that those who praised this...
# 4        9495_8        1.0  Superbly trashy and wondrously unpretentious 8...
# ...         ...        ...                                                ...
# 49995   2155_10        NaN  Sony Pictures Classics, I'm looking at you! So...
# 49996     59_10        NaN  I always felt that Ms. Merkerson had never got...
# 49997    2531_1        NaN  I was so disappointed in this movie. I am very...
# 49998    7772_8        NaN  From the opening sequence, filled with black a...
# 49999  11465_10        NaN  This is a great horror film for people who don...
#
#        is_test
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 49995        1
# 49996        1
# 49997        1
# 49998        1
# 49999        1
#
# [50000 rows x 4 columns]

# %%
# Шаг 3. Проверим пропуски
dataset.isnull().sum()
# Out:
# id               0
# sentiment    25000
# review           0
# is_test          0
# dtype: int64

# %%
def clean_string(text):
    text = BeautifulSoup(text).get_text()  # удаление html тегов
    letters_only = re.sub("[^a-zA-Z]", " ", text)  # удаление символов помимо букв
    words = letters_only.lower().split() # перевод в нижний регистр                           
    stops = set(stopwords.words("english"))                  
    main_words = [w for w in words if not w in stops] # исключение стоп слов   
    return " ".join(main_words)

# %%
# Шаг 4. Очищаем данные с помощью функции clean string
dataset['review_clean'] = dataset['review'].apply(clean_string)

# %%
# Шаг 5. Разделяем данные на тестовые и тренировочные
train_data = dataset.query("is_test == 0")
test_data = dataset.query("is_test == 1")

train_data = train_data.drop(['is_test'], axis=1)
test_data = test_data.drop(['is_test', 'sentiment'], axis=1)

# %%
test_data
# Out:
#              id                                             review  \
# 25000  12311_10  Naturally in a film who's main themes are of m...
# 25001    8348_2  This movie is a disaster within a disaster fil...
# 25002    5828_4  All in all, this is a movie for kids. We saw i...
# 25003    7186_2  Afraid of the Dark left me with the impression...
# 25004   12128_7  A very accurate depiction of small time mob li...
# ...         ...                                                ...
# 49995   2155_10  Sony Pictures Classics, I'm looking at you! So...
# 49996     59_10  I always felt that Ms. Merkerson had never got...
# 49997    2531_1  I was so disappointed in this movie. I am very...
# 49998    7772_8  From the opening sequence, filled with black a...
# 49999  11465_10  This is a great horror film for people who don...
#
#                                             review_clean
# 25000  naturally film main themes mortality nostalgia...
# 25001  movie disaster within disaster film full great...
# 25002  movie kids saw tonight child loved one point k...
# 25003  afraid dark left impression several different ...
# 25004  accurate depiction small time mob life filmed ...
# ...                                                  ...
# 49995  sony pictures classics looking sony got rights...
# 49996  always felt ms merkerson never gotten role fit...
# 49997  disappointed movie familiar case read mark fuh...
# 49998  opening sequence filled black white shots remi...
# 49999  great horror film people want vomit retching g...
#
# [25000 rows x 3 columns]

# %%
# Шаг 6. Создаем векторизатор
vectorizer = CountVectorizer(analyzer = "word", max_features = 9000)

# %%
# Шаг 6.1 Векторизируем тренировочные данные
x = vectorizer.fit_transform(train_data.review_clean)
x = x.toarray()
y = train_data.sentiment

# %%
# Шаг 6.2 Векторизируем тестовые данные
x_test = vectorizer.transform(test_data.review_clean)
x_test = x_test.toarray()

# %%
# Шаг 7. Обучаем рандомный лес
random_forest = RandomForestClassifier(n_estimators = 90)
random_forest.fit(x, y)
# Out:
# RandomForestClassifier(n_estimators=90)

# %%
# Шаг 8. Делаем предикт 
predict = random_forest.predict(x_test)

# %%
predict_fo_csv = pd.DataFrame(data={
    "id": test_data["id"], 
    "sentiment": predict
})
predict_fo_csv.to_csv("words_done.csv", index=False)
